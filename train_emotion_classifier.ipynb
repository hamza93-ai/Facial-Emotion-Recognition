# %% [markdown]
# ## Real-Time Facial Emotion Detection Using Webcam Feed
#
#
# **Dataset:** FER-2013 (7 emotion classes, ~35,000 grayscale 48×48 images)

# %%
import os, sys, time, random, warnings
from collections import deque
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers, applications
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, f1_score
warnings.filterwarnings('ignore')
print("TensorFlow:", tf.__version__)
print("OpenCV:", cv2.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.20.0
# OpenCV: 4.13.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Load Dataset from Kaggle

# %%
import zipfile
from pathlib import Path

with zipfile.ZipFile("/content/archive.zip", 'r') as z:
    z.extractall("/content/fer2013")

DATA_ROOT = Path("/content/fer2013")
print("Done!")
for p in sorted(DATA_ROOT.rglob("*"))[:30]:
    print(" ", p.relative_to(DATA_ROOT))
# Out:
# Done!
#   test
#   test/angry
#   test/angry/PrivateTest_10131363.jpg
#   test/angry/PrivateTest_10304478.jpg
#   test/angry/PrivateTest_1054527.jpg
#   test/angry/PrivateTest_10590091.jpg
#   test/angry/PrivateTest_1109992.jpg
#   test/angry/PrivateTest_11296953.jpg
#   test/angry/PrivateTest_12000629.jpg
#   test/angry/PrivateTest_12008383.jpg
#   test/angry/PrivateTest_12191716.jpg
#   test/angry/PrivateTest_1221822.jpg
#   test/angry/PrivateTest_12403575.jpg
#   test/angry/PrivateTest_12766285.jpg
#   test/angry/PrivateTest_12846357.jpg
#   test/angry/PrivateTest_1290484.jpg
#   test/angry/PrivateTest_12912780.jpg
#   test/angry/PrivateTest_13164119.jpg
#   test/angry/PrivateTest_13278552.jpg
#   test/angry/PrivateTest_13463625.jpg
#   test/angry/PrivateTest_13541561.jpg
#   test/angry/PrivateTest_13664224.jpg
#   test/angry/PrivateTest_14325168.jpg
#   test/angry/PrivateTest_14426977.jpg
#   test/angry/PrivateTest_14433751.jpg
#   test/angry/PrivateTest_14444117.jpg
#   test/angry/PrivateTest_14482875.jpg
#   test/angry/PrivateTest_14494003.jpg
#   test/angry/PrivateTest_14565821.jpg
#   test/angry/PrivateTest_14596578.jpg

# %%
TRAIN_DIR = DATA_ROOT / 'train'
TEST_DIR  = DATA_ROOT / 'test'
EMOTIONS  = sorted([d.name for d in TRAIN_DIR.iterdir() if d.is_dir()])
NUM_CLASSES = len(EMOTIONS)
print("Emotion classes:", EMOTIONS)
print("Num classes:", NUM_CLASSES)
train_counts = {e: len(list((TRAIN_DIR/e).glob('*.jpg'))) for e in EMOTIONS}
test_counts  = {e: len(list((TEST_DIR/e).glob('*.jpg')))  for e in EMOTIONS}
print("\nTrain samples per class:", train_counts)
print("Test samples per class: ", test_counts)
# Out:
# Emotion classes: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
# Num classes: 7
#
# Train samples per class: {'angry': 3995, 'disgust': 436, 'fear': 4097, 'happy': 7215, 'neutral': 4965, 'sad': 4830, 'surprise': 3171}
# Test samples per class:  {'angry': 958, 'disgust': 111, 'fear': 1024, 'happy': 1774, 'neutral': 1233, 'sad': 1247, 'surprise': 831}

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 4))
for ax, counts, title in zip(axes,
                              [train_counts, test_counts],
                              ['Train Set Distribution', 'Test Set Distribution']):
    bars = ax.bar(counts.keys(), counts.values(),
                  color=plt.cm.Set2(np.linspace(0, 1, NUM_CLASSES)))
    ax.set_title(title, fontsize=13, fontweight='bold')
    ax.set_xlabel('Emotion')
    ax.set_ylabel('Sample Count')
    for bar, val in zip(bars, counts.values()):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 50,
                str(val), ha='center', va='bottom', fontsize=9)
plt.tight_layout()
plt.savefig('class_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
print("Total train samples:", sum(train_counts.values()))
print("Total test  samples:", sum(test_counts.values()))
# Out:
# Total train samples: 28709
# Total test  samples: 7178

# %% [markdown]
# Image Preprocessing

# %%
IMG_SIZE_GRAY = 48
IMG_SIZE_COLOR = 96
BATCH_SIZE = 64
EPOCHS_SCRATCH = 50
EPOCHS_FINETUNE = 20
def preprocess_face_gray(img_bgr):
    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    eq = clahe.apply(blurred)
    resized = cv2.resize(eq, (IMG_SIZE_GRAY, IMG_SIZE_GRAY))
    norm = resized.astype('float32') / 255.0
    return norm[..., np.newaxis]

def preprocess_face_color(img_bgr):
    rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(rgb, (IMG_SIZE_COLOR, IMG_SIZE_COLOR))
    return applications.mobilenet_v2.preprocess_input(resized.astype('float32'))
print("Preprocessing functions defined.")
# Out:
# Preprocessing functions defined.

# %%
fig, axes = plt.subplots(len(EMOTIONS), 5, figsize=(14, 2.5 * len(EMOTIONS)))
steps = ['Original', 'Grayscale', 'Gaussian Blur', 'CLAHE', 'Final (norm)']
for row, emotion in enumerate(EMOTIONS):
    img_path = list((TRAIN_DIR / emotion).glob('*.jpg'))[0]
    img_bgr = cv2.imread(str(img_path))
    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    eq = clahe.apply(blurred)
    resized = cv2.resize(eq, (IMG_SIZE_GRAY, IMG_SIZE_GRAY))
    imgs = [cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB), gray, blurred, eq, resized]
    cmaps = [None, 'gray', 'gray', 'gray', 'gray']
    for col, (im, cmap, step) in enumerate(zip(imgs, cmaps, steps)):
        axes[row, col].imshow(im, cmap=cmap)
        axes[row, col].axis('off')
        if row == 0:
            axes[row, col].set_title(step, fontsize=10, fontweight='bold')
        if col == 0:
            axes[row, col].set_ylabel(emotion, fontsize=9, rotation=90, labelpad=10)
plt.suptitle('Preprocessing Pipeline per Emotion Class', fontsize=14, y=1.01)
plt.tight_layout()
plt.savefig('preprocessing_pipeline.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
def load_and_preprocess_gray(file_path, label):#For CNN and VGG
    raw = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(raw, channels=1)
    img = tf.image.resize(img, [IMG_SIZE_GRAY, IMG_SIZE_GRAY])
    img = tf.cast(img, tf.float32) / 255.0
    return img, label

def load_and_preprocess_color(file_path, label):#For mobilenet
    raw = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(raw, channels=3)
    img = tf.image.resize(img, [IMG_SIZE_COLOR, IMG_SIZE_COLOR])
    img = tf.keras.applications.mobilenet_v2.preprocess_input(tf.cast(img, tf.float32))
    return img, label

def augment(img, label):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, max_delta=0.1)
    img = tf.image.random_contrast(img, lower=0.8, upper=1.2)
    return img, label

def build_dataset(directory, preprocess_fn, augment_data=False, shuffle=True):
    file_paths, labels = [], []
    for idx, emotion in enumerate(EMOTIONS):
        imgs = list((directory / emotion).glob('*.jpg'))
        file_paths.extend([str(p) for p in imgs])
        labels.extend([idx] * len(imgs))
    ds = tf.data.Dataset.from_tensor_slices(
            (file_paths, tf.one_hot(labels, NUM_CLASSES)))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(file_paths), seed=42)
    ds = ds.map(preprocess_fn, num_parallel_calls=tf.data.AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds
train_ds_gray = build_dataset(TRAIN_DIR,load_and_preprocess_gray, augment_data=True)
val_ds_gray = build_dataset(TEST_DIR,load_and_preprocess_gray, augment_data=False, shuffle=False)
train_ds_color = build_dataset(TRAIN_DIR,load_and_preprocess_color, augment_data=True)
val_ds_color = build_dataset(TEST_DIR,load_and_preprocess_color, augment_data=False, shuffle=False)

print("Gray train batches :", len(train_ds_gray))
print("Gray val batches :", len(val_ds_gray))
print("Color train batches:", len(train_ds_color))
# Out:
# Gray train batches : 449
# Gray val batches : 113
# Color train batches: 449

# %%
def build_scratch_cnn(input_shape=(48, 48, 1), num_classes=7):#CNN
    inp = layers.Input(shape=input_shape, name='input')
    #First Block with 32 filters
    x = layers.Conv2D(32, 3, padding='same', activation='relu')(inp)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(32, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.25)(x)
    #Second Block with 64 filters
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.25)(x)
    #Third Block with 128
    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.25)(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    out = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inp, out, name='scratch_cnn')
    return model
scratch_model = build_scratch_cnn()
scratch_model.summary()
print(f"\nTrainable params: {scratch_model.count_params():,}")
# Out:
# Model: "scratch_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 48, 48, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 323,047 (1.23 MB)
#  Trainable params: 322,151 (1.23 MB)
#  Non-trainable params: 896 (3.50 KB)
# Trainable params: 323,047

# %%
def build_pretrained_model(input_shape=(96, 96, 3), num_classes=7, trainable=False):
    base = applications.MobileNetV2(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )

    if not trainable:
        base.trainable = False        # Freeze all backbone layers
    else:
        base.trainable = True
        # Unfreeze only the last 30 layers for fine-tuning
        for layer in base.layers[:-30]:
            layer.trainable = False

    inp = layers.Input(shape=input_shape, name='input_color')
    x   = base(inp, training=False)
    x   = layers.GlobalAveragePooling2D()(x)
    x   = layers.Dense(512, activation='relu')(x)
    x   = layers.Dropout(0.4)(x)
    x   = layers.Dense(256, activation='relu')(x)
    x   = layers.Dropout(0.3)(x)
    out = layers.Dense(num_classes, activation='softmax')(x)

    name = 'mobilenetv2_frozen' if not trainable else 'mobilenetv2_finetuned'
    model = models.Model(inp, out, name=name)
    return model


pretrained_frozen_model = build_pretrained_model(trainable=False)
pretrained_frozen_model.summary()
print(f"\nTrainable params: {pretrained_frozen_model.count_params():,}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_96_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "mobilenetv2_frozen"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_color (InputLayer)        │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_96             │ (None, 3, 3, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,046,983 (11.62 MB)
#  Trainable params: 788,999 (3.01 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Trainable params: 3,046,983

# %%
# ──────── Architecture 3: VGG-Style Double Conv Block Variant ────────────────

def vgg_double_conv_block(x, filters, dropout_rate=0.3, name=''):
    """
    VGG-style double conv block:
      Conv(3×3) → BN → ReLU → Conv(3×3) → BN → ReLU → MaxPool → Dropout
    This mirrors the VGG philosophy of stacking small receptive-field convolutions
    before pooling, giving a larger effective receptive field with fewer parameters.
    """
    x = layers.Conv2D(filters, 3, padding='same', name=f'{name}_conv1')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(filters, 3, padding='same', name=f'{name}_conv2')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(dropout_rate)(x)
    return x


def build_vgg_style_model(input_shape=(48, 48, 1), num_classes=7):
    """
    VGG-style model: 4 double-conv blocks → flatten → dense head.
    Variant: uses BatchNorm after each conv (unlike original VGG which did not).
    Input: (48, 48, 1) grayscale, normalised.
    """
    inp = layers.Input(shape=input_shape, name='input_vgg')

    x = vgg_double_conv_block(inp, 32,  dropout_rate=0.25, name='block1')
    x = vgg_double_conv_block(x,   64,  dropout_rate=0.25, name='block2')
    x = vgg_double_conv_block(x,   128, dropout_rate=0.30, name='block3')

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.4)(x)
    out = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inp, out, name='vgg_style')
    return model


vgg_model = build_vgg_style_model()
vgg_model.summary()
print(f"\nTrainable params: {vgg_model.count_params():,}")
# Out:
# Model: "vgg_style"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_vgg (InputLayer)          │ (None, 48, 48, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 48, 48, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 24, 24, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 487,399 (1.86 MB)
#  Trainable params: 486,503 (1.86 MB)
#  Non-trainable params: 896 (3.50 KB)
# Trainable params: 487,399

# %% [markdown]
# ## Section 6 — Training All Three Models

# %%
# ─────────────────── Shared training utilities ─────────────────────────────

def get_callbacks(model_name):
    """Return standard set of Keras callbacks."""
    return [
        callbacks.ModelCheckpoint(
            filepath=f'best_{model_name}.keras',
            monitor='val_accuracy', save_best_only=True, verbose=1),
        callbacks.EarlyStopping(
            monitor='val_accuracy', patience=8,
            restore_best_weights=True, verbose=1),
        callbacks.ReduceLROnPlateau(
            monitor='val_loss', factor=0.5, patience=4,
            min_lr=1e-6, verbose=1),
    ]


def compile_and_train(model, train_ds, val_ds, epochs, lr=1e-3, model_name='model'):
    """Compile with Adam + categorical crossentropy, then train."""
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    t0 = time.time()
    history = model.fit(
        train_ds, validation_data=val_ds,
        epochs=epochs,
        callbacks=get_callbacks(model_name),
        verbose=1
    )
    elapsed = time.time() - t0
    print(f"\n⏱  Training time: {elapsed/60:.1f} min")
    return history, elapsed


def plot_history(history, title):
    """Plot training / validation accuracy and loss curves."""
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    for ax, metric in zip(axes, ['accuracy', 'loss']):
        ax.plot(history.history[metric],       label='Train', linewidth=2)
        ax.plot(history.history[f'val_{metric}'], label='Val',   linewidth=2)
        ax.set_title(f'{title} — {metric.capitalize()}', fontsize=12)
        ax.set_xlabel('Epoch')
        ax.legend()
        ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(f'{title.lower().replace(" ","_")}_history.png',
                dpi=150, bbox_inches='tight')
    plt.show()

print("Utilities defined.")
# Out:
# Utilities defined.

# %%
# ──────────────────── Train Model 1: CNN Scratch ───────────────────────────
print("=" * 60)
print("TRAINING MODEL 1: CNN from Scratch")
print("=" * 60)

scratch_model = build_scratch_cnn()
history_scratch, time_scratch = compile_and_train(
    scratch_model, train_ds_gray, val_ds_gray,
    epochs=EPOCHS_SCRATCH, lr=1e-3, model_name='scratch_cnn'
)
plot_history(history_scratch, 'CNN Scratch')
# Out:
# ============================================================
# TRAINING MODEL 1: CNN from Scratch
# ============================================================
# Epoch 1/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.2403 - loss: 1.8705
# Epoch 1: val_accuracy improved from None to 0.29674, saving model to best_scratch_cnn.keras
#
# Epoch 1: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 33s 46ms/step - accuracy: 0.2843 - loss: 1.7570 - val_accuracy: 0.2967 - val_loss: 1.7389 - learning_rate: 0.0010
# Epoch 2/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4270 - loss: 1.4711
# Epoch 2: val_accuracy improved from 0.29674 to 0.48607, saving model to best_scratch_cnn.keras
#
# Epoch 2: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.4530 - loss: 1.4173 - val_accuracy: 0.4861 - val_loss: 1.3597 - learning_rate: 0.0010
# Epoch 3/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5092 - loss: 1.2877
# Epoch 3: val_accuracy improved from 0.48607 to 0.53441, saving model to best_scratch_cnn.keras
#
# Epoch 3: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.5126 - loss: 1.2797 - val_accuracy: 0.5344 - val_loss: 1.2187 - learning_rate: 0.0010
# Epoch 4/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5426 - loss: 1.2055
# Epoch 4: val_accuracy improved from 0.53441 to 0.54486, saving model to best_scratch_cnn.keras
#
# Epoch 4: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.5502 - loss: 1.1964 - val_accuracy: 0.5449 - val_loss: 1.2094 - learning_rate: 0.0010
# Epoch 5/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5620 - loss: 1.1544
# Epoch 5: val_accuracy improved from 0.54486 to 0.55155, saving model to best_scratch_cnn.keras
#
# Epoch 5: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.5683 - loss: 1.1462 - val_accuracy: 0.5515 - val_loss: 1.1891 - learning_rate: 0.0010
# Epoch 6/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5795 - loss: 1.1191
# Epoch 6: val_accuracy improved from 0.55155 to 0.57871, saving model to best_scratch_cnn.keras
#
# Epoch 6: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.5801 - loss: 1.1193 - val_accuracy: 0.5787 - val_loss: 1.0959 - learning_rate: 0.0010
# Epoch 7/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5941 - loss: 1.0822
# Epoch 7: val_accuracy did not improve from 0.57871
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.5912 - loss: 1.0881 - val_accuracy: 0.5748 - val_loss: 1.1623 - learning_rate: 0.0010
# Epoch 8/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6037 - loss: 1.0570
# Epoch 8: val_accuracy did not improve from 0.57871
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6027 - loss: 1.0602 - val_accuracy: 0.5653 - val_loss: 1.1747 - learning_rate: 0.0010
# Epoch 9/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6180 - loss: 1.0312
# Epoch 9: val_accuracy improved from 0.57871 to 0.60212, saving model to best_scratch_cnn.keras
#
# Epoch 9: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6147 - loss: 1.0371 - val_accuracy: 0.6021 - val_loss: 1.0552 - learning_rate: 0.0010
# Epoch 10/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6223 - loss: 1.0089
# Epoch 10: val_accuracy improved from 0.60212 to 0.60811, saving model to best_scratch_cnn.keras
#
# Epoch 10: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6172 - loss: 1.0186 - val_accuracy: 0.6081 - val_loss: 1.0492 - learning_rate: 0.0010
# Epoch 11/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6292 - loss: 0.9947
# Epoch 11: val_accuracy did not improve from 0.60811
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6289 - loss: 0.9913 - val_accuracy: 0.5914 - val_loss: 1.1063 - learning_rate: 0.0010
# Epoch 12/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6363 - loss: 0.9769
# Epoch 12: val_accuracy improved from 0.60811 to 0.61257, saving model to best_scratch_cnn.keras
#
# Epoch 12: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.6352 - loss: 0.9795 - val_accuracy: 0.6126 - val_loss: 1.0440 - learning_rate: 0.0010
# Epoch 13/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6426 - loss: 0.9574
# Epoch 13: val_accuracy improved from 0.61257 to 0.61619, saving model to best_scratch_cnn.keras
#
# Epoch 13: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6370 - loss: 0.9665 - val_accuracy: 0.6162 - val_loss: 1.0221 - learning_rate: 0.0010
# Epoch 14/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6454 - loss: 0.9475
# Epoch 14: val_accuracy improved from 0.61619 to 0.61967, saving model to best_scratch_cnn.keras
#
# Epoch 14: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6448 - loss: 0.9480 - val_accuracy: 0.6197 - val_loss: 1.0186 - learning_rate: 0.0010
# Epoch 15/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6536 - loss: 0.9249
# Epoch 15: val_accuracy did not improve from 0.61967
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6488 - loss: 0.9373 - val_accuracy: 0.6149 - val_loss: 1.0179 - learning_rate: 0.0010
# Epoch 16/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6553 - loss: 0.9206
# Epoch 16: val_accuracy improved from 0.61967 to 0.62469, saving model to best_scratch_cnn.keras
#
# Epoch 16: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6546 - loss: 0.9246 - val_accuracy: 0.6247 - val_loss: 1.0181 - learning_rate: 0.0010
# Epoch 17/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6560 - loss: 0.9158
# Epoch 17: val_accuracy did not improve from 0.62469
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6555 - loss: 0.9186 - val_accuracy: 0.6233 - val_loss: 1.0350 - learning_rate: 0.0010
# Epoch 18/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6684 - loss: 0.8829
# Epoch 18: val_accuracy improved from 0.62469 to 0.62956, saving model to best_scratch_cnn.keras
#
# Epoch 18: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.6632 - loss: 0.8988 - val_accuracy: 0.6296 - val_loss: 0.9882 - learning_rate: 0.0010
# Epoch 19/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6689 - loss: 0.8850
# Epoch 19: val_accuracy improved from 0.62956 to 0.63318, saving model to best_scratch_cnn.keras
#
# Epoch 19: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6670 - loss: 0.8902 - val_accuracy: 0.6332 - val_loss: 0.9926 - learning_rate: 0.0010
# Epoch 20/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6743 - loss: 0.8724
# Epoch 20: val_accuracy improved from 0.63318 to 0.63876, saving model to best_scratch_cnn.keras
#
# Epoch 20: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6735 - loss: 0.8729 - val_accuracy: 0.6388 - val_loss: 0.9611 - learning_rate: 0.0010
# Epoch 21/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6764 - loss: 0.8615
# Epoch 21: val_accuracy did not improve from 0.63876
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6758 - loss: 0.8653 - val_accuracy: 0.6286 - val_loss: 1.0299 - learning_rate: 0.0010
# Epoch 22/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6793 - loss: 0.8541
# Epoch 22: val_accuracy improved from 0.63876 to 0.64196, saving model to best_scratch_cnn.keras
#
# Epoch 22: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6810 - loss: 0.8562 - val_accuracy: 0.6420 - val_loss: 0.9703 - learning_rate: 0.0010
# Epoch 23/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6898 - loss: 0.8303
# Epoch 23: val_accuracy did not improve from 0.64196
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6842 - loss: 0.8424 - val_accuracy: 0.6364 - val_loss: 0.9902 - learning_rate: 0.0010
# Epoch 24/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6905 - loss: 0.8336
# Epoch 24: val_accuracy improved from 0.64196 to 0.64684, saving model to best_scratch_cnn.keras
#
# Epoch 24: finished saving model to best_scratch_cnn.keras
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.6855 - loss: 0.8401 - val_accuracy: 0.6468 - val_loss: 0.9612 - learning_rate: 0.0010
# Epoch 25/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7010 - loss: 0.7958
# Epoch 25: val_accuracy did not improve from 0.64684
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7041 - loss: 0.7919 - val_accuracy: 0.6466 - val_loss: 0.9661 - learning_rate: 5.0000e-04
# Epoch 26/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7110 - loss: 0.7795
# Epoch 26: val_accuracy improved from 0.64684 to 0.65729, saving model to best_scratch_cnn.keras
#
# Epoch 26: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7110 - loss: 0.7783 - val_accuracy: 0.6573 - val_loss: 0.9575 - learning_rate: 5.0000e-04
# Epoch 27/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7148 - loss: 0.7621
# Epoch 27: val_accuracy improved from 0.65729 to 0.65756, saving model to best_scratch_cnn.keras
#
# Epoch 27: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.7131 - loss: 0.7686 - val_accuracy: 0.6576 - val_loss: 0.9445 - learning_rate: 5.0000e-04
# Epoch 28/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7141 - loss: 0.7574
# Epoch 28: val_accuracy did not improve from 0.65756
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7173 - loss: 0.7551 - val_accuracy: 0.6502 - val_loss: 0.9828 - learning_rate: 5.0000e-04
# Epoch 29/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7247 - loss: 0.7384
# Epoch 29: val_accuracy improved from 0.65756 to 0.66411, saving model to best_scratch_cnn.keras
#
# Epoch 29: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.7213 - loss: 0.7491 - val_accuracy: 0.6641 - val_loss: 0.9395 - learning_rate: 5.0000e-04
# Epoch 30/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7170 - loss: 0.7443
# Epoch 30: val_accuracy did not improve from 0.66411
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.7189 - loss: 0.7433 - val_accuracy: 0.6525 - val_loss: 0.9954 - learning_rate: 5.0000e-04
# Epoch 31/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7270 - loss: 0.7262
# Epoch 31: val_accuracy improved from 0.66411 to 0.66648, saving model to best_scratch_cnn.keras
#
# Epoch 31: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7268 - loss: 0.7276 - val_accuracy: 0.6665 - val_loss: 0.9494 - learning_rate: 5.0000e-04
# Epoch 32/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7276 - loss: 0.7231
# Epoch 32: val_accuracy did not improve from 0.66648
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7272 - loss: 0.7225 - val_accuracy: 0.6610 - val_loss: 0.9561 - learning_rate: 5.0000e-04
# Epoch 33/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7362 - loss: 0.7119
# Epoch 33: val_accuracy did not improve from 0.66648
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7325 - loss: 0.7186 - val_accuracy: 0.6605 - val_loss: 0.9743 - learning_rate: 5.0000e-04
# Epoch 34/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7347 - loss: 0.6985
# Epoch 34: val_accuracy improved from 0.66648 to 0.66996, saving model to best_scratch_cnn.keras
#
# Epoch 34: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.7379 - loss: 0.6962 - val_accuracy: 0.6700 - val_loss: 0.9527 - learning_rate: 2.5000e-04
# Epoch 35/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7461 - loss: 0.6817
# Epoch 35: val_accuracy did not improve from 0.66996
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7448 - loss: 0.6848 - val_accuracy: 0.6682 - val_loss: 0.9593 - learning_rate: 2.5000e-04
# Epoch 36/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7479 - loss: 0.6793
# Epoch 36: val_accuracy improved from 0.66996 to 0.67150, saving model to best_scratch_cnn.keras
#
# Epoch 36: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7506 - loss: 0.6715 - val_accuracy: 0.6715 - val_loss: 0.9659 - learning_rate: 2.5000e-04
# Epoch 37/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7552 - loss: 0.6607
# Epoch 37: val_accuracy improved from 0.67150 to 0.67247, saving model to best_scratch_cnn.keras
#
# Epoch 37: finished saving model to best_scratch_cnn.keras
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7524 - loss: 0.6667 - val_accuracy: 0.6725 - val_loss: 0.9489 - learning_rate: 2.5000e-04
# Epoch 38/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7609 - loss: 0.6481
# Epoch 38: val_accuracy improved from 0.67247 to 0.67554, saving model to best_scratch_cnn.keras
#
# Epoch 38: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7545 - loss: 0.6555 - val_accuracy: 0.6755 - val_loss: 0.9455 - learning_rate: 1.2500e-04
# Epoch 39/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7572 - loss: 0.6533
# Epoch 39: val_accuracy did not improve from 0.67554
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7565 - loss: 0.6565 - val_accuracy: 0.6733 - val_loss: 0.9554 - learning_rate: 1.2500e-04
# Epoch 40/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7549 - loss: 0.6545
# Epoch 40: val_accuracy did not improve from 0.67554
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7578 - loss: 0.6474 - val_accuracy: 0.6716 - val_loss: 0.9632 - learning_rate: 1.2500e-04
# Epoch 41/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7606 - loss: 0.6340
# Epoch 41: val_accuracy did not improve from 0.67554
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7575 - loss: 0.6415 - val_accuracy: 0.6722 - val_loss: 0.9600 - learning_rate: 1.2500e-04
# Epoch 42/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7663 - loss: 0.6233
# Epoch 42: val_accuracy did not improve from 0.67554
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7612 - loss: 0.6320 - val_accuracy: 0.6721 - val_loss: 0.9608 - learning_rate: 6.2500e-05
# Epoch 43/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7634 - loss: 0.6372
# Epoch 43: val_accuracy did not improve from 0.67554
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7620 - loss: 0.6339 - val_accuracy: 0.6737 - val_loss: 0.9596 - learning_rate: 6.2500e-05
# Epoch 44/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7601 - loss: 0.6348
# Epoch 44: val_accuracy improved from 0.67554 to 0.67637, saving model to best_scratch_cnn.keras
#
# Epoch 44: finished saving model to best_scratch_cnn.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.7601 - loss: 0.6338 - val_accuracy: 0.6764 - val_loss: 0.9559 - learning_rate: 6.2500e-05
# Epoch 45/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7601 - loss: 0.6348
# Epoch 45: val_accuracy improved from 0.67637 to 0.67707, saving model to best_scratch_cnn.keras
#
# Epoch 45: finished saving model to best_scratch_cnn.keras
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7634 - loss: 0.6303 - val_accuracy: 0.6771 - val_loss: 0.9601 - learning_rate: 6.2500e-05
# Epoch 46/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7622 - loss: 0.6366
# Epoch 46: val_accuracy did not improve from 0.67707
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7651 - loss: 0.6296 - val_accuracy: 0.6747 - val_loss: 0.9588 - learning_rate: 3.1250e-05
# Epoch 47/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7698 - loss: 0.6173
# Epoch 47: val_accuracy did not improve from 0.67707
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7704 - loss: 0.6213 - val_accuracy: 0.6764 - val_loss: 0.9608 - learning_rate: 3.1250e-05
# Epoch 48/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7727 - loss: 0.6121
# Epoch 48: val_accuracy did not improve from 0.67707
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7685 - loss: 0.6154 - val_accuracy: 0.6761 - val_loss: 0.9625 - learning_rate: 3.1250e-05
# Epoch 49/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7681 - loss: 0.6181
# Epoch 49: val_accuracy did not improve from 0.67707
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7683 - loss: 0.6204 - val_accuracy: 0.6739 - val_loss: 0.9622 - learning_rate: 3.1250e-05
# Epoch 50/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7694 - loss: 0.6147
# Epoch 50: val_accuracy did not improve from 0.67707
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7697 - loss: 0.6206 - val_accuracy: 0.6761 - val_loss: 0.9614 - learning_rate: 1.5625e-05
# Restoring model weights from the end of the best epoch: 45.
#
# ⏱  Training time: 7.9 min

# %%
# ──────── Train Model 2a: MobileNetV2 Frozen (feature extractor) ──────────
print("=" * 60)
print("TRAINING MODEL 2a: MobileNetV2 Frozen Backbone")
print("=" * 60)

pretrained_frozen_model = build_pretrained_model(trainable=False)
history_frozen, time_frozen = compile_and_train(
    pretrained_frozen_model, train_ds_color, val_ds_color,
    epochs=20, lr=1e-3, model_name='mobilenet_frozen'
)
plot_history(history_frozen, 'MobileNetV2 Frozen')
# Out:
# ============================================================
# TRAINING MODEL 2a: MobileNetV2 Frozen Backbone
# ============================================================
# Epoch 1/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3355 - loss: 1.7360
# Epoch 1: val_accuracy improved from None to 0.45096, saving model to best_mobilenet_frozen.keras
#
# Epoch 1: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 86ms/step - accuracy: 0.3754 - loss: 1.6109 - val_accuracy: 0.4510 - val_loss: 1.4472 - learning_rate: 0.0010
# Epoch 2/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4228 - loss: 1.4876
# Epoch 2: val_accuracy improved from 0.45096 to 0.47060, saving model to best_mobilenet_frozen.keras
#
# Epoch 2: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.4295 - loss: 1.4784 - val_accuracy: 0.4706 - val_loss: 1.4015 - learning_rate: 0.0010
# Epoch 3/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4546 - loss: 1.4243
# Epoch 3: val_accuracy improved from 0.47060 to 0.47506, saving model to best_mobilenet_frozen.keras
#
# Epoch 3: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.4521 - loss: 1.4322 - val_accuracy: 0.4751 - val_loss: 1.3707 - learning_rate: 0.0010
# Epoch 4/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4624 - loss: 1.3982
# Epoch 4: val_accuracy improved from 0.47506 to 0.48189, saving model to best_mobilenet_frozen.keras
#
# Epoch 4: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.4647 - loss: 1.4022 - val_accuracy: 0.4819 - val_loss: 1.3506 - learning_rate: 0.0010
# Epoch 5/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4821 - loss: 1.3654
# Epoch 5: val_accuracy improved from 0.48189 to 0.48495, saving model to best_mobilenet_frozen.keras
#
# Epoch 5: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.4782 - loss: 1.3713 - val_accuracy: 0.4850 - val_loss: 1.3396 - learning_rate: 0.0010
# Epoch 6/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4862 - loss: 1.3432
# Epoch 6: val_accuracy improved from 0.48495 to 0.49540, saving model to best_mobilenet_frozen.keras
#
# Epoch 6: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.4844 - loss: 1.3476 - val_accuracy: 0.4954 - val_loss: 1.3254 - learning_rate: 0.0010
# Epoch 7/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4990 - loss: 1.3184
# Epoch 7: val_accuracy improved from 0.49540 to 0.49735, saving model to best_mobilenet_frozen.keras
#
# Epoch 7: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.4922 - loss: 1.3308 - val_accuracy: 0.4974 - val_loss: 1.3122 - learning_rate: 0.0010
# Epoch 8/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5122 - loss: 1.2942
# Epoch 8: val_accuracy did not improve from 0.49735
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.5034 - loss: 1.3079 - val_accuracy: 0.4955 - val_loss: 1.3263 - learning_rate: 0.0010
# Epoch 9/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5107 - loss: 1.2829
# Epoch 9: val_accuracy improved from 0.49735 to 0.50571, saving model to best_mobilenet_frozen.keras
#
# Epoch 9: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.5072 - loss: 1.2957 - val_accuracy: 0.5057 - val_loss: 1.3031 - learning_rate: 0.0010
# Epoch 10/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5172 - loss: 1.2602
# Epoch 10: val_accuracy improved from 0.50571 to 0.50794, saving model to best_mobilenet_frozen.keras
#
# Epoch 10: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.5126 - loss: 1.2786 - val_accuracy: 0.5079 - val_loss: 1.2992 - learning_rate: 0.0010
# Epoch 11/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5218 - loss: 1.2566
# Epoch 11: val_accuracy improved from 0.50794 to 0.50961, saving model to best_mobilenet_frozen.keras
#
# Epoch 11: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.5207 - loss: 1.2589 - val_accuracy: 0.5096 - val_loss: 1.2883 - learning_rate: 0.0010
# Epoch 12/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5320 - loss: 1.2382
# Epoch 12: val_accuracy improved from 0.50961 to 0.51477, saving model to best_mobilenet_frozen.keras
#
# Epoch 12: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.5317 - loss: 1.2393 - val_accuracy: 0.5148 - val_loss: 1.2844 - learning_rate: 0.0010
# Epoch 13/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5282 - loss: 1.2239
# Epoch 13: val_accuracy did not improve from 0.51477
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.5289 - loss: 1.2298 - val_accuracy: 0.5145 - val_loss: 1.2869 - learning_rate: 0.0010
# Epoch 14/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5365 - loss: 1.2090
# Epoch 14: val_accuracy did not improve from 0.51477
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.5355 - loss: 1.2174 - val_accuracy: 0.5130 - val_loss: 1.2780 - learning_rate: 0.0010
# Epoch 15/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5420 - loss: 1.1947
# Epoch 15: val_accuracy improved from 0.51477 to 0.52494, saving model to best_mobilenet_frozen.keras
#
# Epoch 15: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.5412 - loss: 1.2025 - val_accuracy: 0.5249 - val_loss: 1.2864 - learning_rate: 0.0010
# Epoch 16/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5526 - loss: 1.1711
# Epoch 16: val_accuracy did not improve from 0.52494
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.5487 - loss: 1.1788 - val_accuracy: 0.5202 - val_loss: 1.2791 - learning_rate: 0.0010
# Epoch 17/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5531 - loss: 1.1774
# Epoch 17: val_accuracy improved from 0.52494 to 0.52689, saving model to best_mobilenet_frozen.keras
#
# Epoch 17: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.5502 - loss: 1.1778 - val_accuracy: 0.5269 - val_loss: 1.2655 - learning_rate: 0.0010
# Epoch 18/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5681 - loss: 1.1505
# Epoch 18: val_accuracy improved from 0.52689 to 0.52744, saving model to best_mobilenet_frozen.keras
#
# Epoch 18: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.5586 - loss: 1.1646 - val_accuracy: 0.5274 - val_loss: 1.2761 - learning_rate: 0.0010
# Epoch 19/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5631 - loss: 1.1482
# Epoch 19: val_accuracy did not improve from 0.52744
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.5638 - loss: 1.1500 - val_accuracy: 0.5258 - val_loss: 1.2742 - learning_rate: 0.0010
# Epoch 20/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5722 - loss: 1.1288
# Epoch 20: val_accuracy did not improve from 0.52744
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.5686 - loss: 1.1382 - val_accuracy: 0.5263 - val_loss: 1.2785 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 18.
#
# ⏱  Training time: 5.1 min

# %%
# ── Train Model 2b: MobileNetV2 Fine-tuned (last 30 layers unfrozen) ──────
print("=" * 60)
print("TRAINING MODEL 2b: MobileNetV2 Fine-tuned")
print("=" * 60)

# Load the frozen model weights then unfreeze last 30 layers
finetuned_model = build_pretrained_model(trainable=True)
# Warm-start: copy weights from frozen head layers if sizes match
history_finetune, time_finetune = compile_and_train(
    finetuned_model, train_ds_color, val_ds_color,
    epochs=EPOCHS_FINETUNE, lr=1e-4,   # Lower LR for fine-tuning
    model_name='mobilenet_finetuned'
)
plot_history(history_finetune, 'MobileNetV2 Fine-tuned')
# Out:
# ============================================================
# TRAINING MODEL 2b: MobileNetV2 Fine-tuned
# ============================================================
# Epoch 1/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3260 - loss: 1.7582
# Epoch 1: val_accuracy improved from None to 0.45737, saving model to best_mobilenet_finetuned.keras
#
# Epoch 1: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 47s 64ms/step - accuracy: 0.3928 - loss: 1.5789 - val_accuracy: 0.4574 - val_loss: 1.4273 - learning_rate: 1.0000e-04
# Epoch 2/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5165 - loss: 1.2916
# Epoch 2: val_accuracy improved from 0.45737 to 0.50947, saving model to best_mobilenet_finetuned.keras
#
# Epoch 2: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.5204 - loss: 1.2733 - val_accuracy: 0.5095 - val_loss: 1.2790 - learning_rate: 1.0000e-04
# Epoch 3/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5688 - loss: 1.1482
# Epoch 3: val_accuracy improved from 0.50947 to 0.51212, saving model to best_mobilenet_finetuned.keras
#
# Epoch 3: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.5712 - loss: 1.1400 - val_accuracy: 0.5121 - val_loss: 1.2797 - learning_rate: 1.0000e-04
# Epoch 4/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6191 - loss: 1.0301
# Epoch 4: val_accuracy improved from 0.51212 to 0.52410, saving model to best_mobilenet_finetuned.keras
#
# Epoch 4: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.6164 - loss: 1.0299 - val_accuracy: 0.5241 - val_loss: 1.3068 - learning_rate: 1.0000e-04
# Epoch 5/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6531 - loss: 0.9249
# Epoch 5: val_accuracy improved from 0.52410 to 0.52522, saving model to best_mobilenet_finetuned.keras
#
# Epoch 5: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.6556 - loss: 0.9273 - val_accuracy: 0.5252 - val_loss: 1.3013 - learning_rate: 1.0000e-04
# Epoch 6/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7064 - loss: 0.8124
# Epoch 6: val_accuracy did not improve from 0.52522
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7019 - loss: 0.8221 - val_accuracy: 0.5164 - val_loss: 1.4325 - learning_rate: 1.0000e-04
# Epoch 7/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7575 - loss: 0.6676
# Epoch 7: val_accuracy improved from 0.52522 to 0.55726, saving model to best_mobilenet_finetuned.keras
#
# Epoch 7: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.7587 - loss: 0.6619 - val_accuracy: 0.5573 - val_loss: 1.3894 - learning_rate: 5.0000e-05
# Epoch 8/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7941 - loss: 0.5753
# Epoch 8: val_accuracy improved from 0.55726 to 0.58261, saving model to best_mobilenet_finetuned.keras
#
# Epoch 8: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.7898 - loss: 0.5825 - val_accuracy: 0.5826 - val_loss: 1.3742 - learning_rate: 5.0000e-05
# Epoch 9/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8117 - loss: 0.5168
# Epoch 9: val_accuracy improved from 0.58261 to 0.58442, saving model to best_mobilenet_finetuned.keras
#
# Epoch 9: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.8103 - loss: 0.5227 - val_accuracy: 0.5844 - val_loss: 1.4089 - learning_rate: 5.0000e-05
# Epoch 10/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8385 - loss: 0.4489
# Epoch 10: val_accuracy improved from 0.58442 to 0.58902, saving model to best_mobilenet_finetuned.keras
#
# Epoch 10: finished saving model to best_mobilenet_finetuned.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.8363 - loss: 0.4594 - val_accuracy: 0.5890 - val_loss: 1.5908 - learning_rate: 5.0000e-05
# Epoch 11/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8615 - loss: 0.3881
# Epoch 11: val_accuracy improved from 0.58902 to 0.59822, saving model to best_mobilenet_finetuned.keras
#
# Epoch 11: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.8651 - loss: 0.3776 - val_accuracy: 0.5982 - val_loss: 1.5210 - learning_rate: 2.5000e-05
# Epoch 12/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8798 - loss: 0.3440
# Epoch 12: val_accuracy improved from 0.59822 to 0.59877, saving model to best_mobilenet_finetuned.keras
#
# Epoch 12: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.8801 - loss: 0.3404 - val_accuracy: 0.5988 - val_loss: 1.5706 - learning_rate: 2.5000e-05
# Epoch 13/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8860 - loss: 0.3173
# Epoch 13: val_accuracy improved from 0.59877 to 0.60407, saving model to best_mobilenet_finetuned.keras
#
# Epoch 13: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.8868 - loss: 0.3203 - val_accuracy: 0.6041 - val_loss: 1.6094 - learning_rate: 2.5000e-05
# Epoch 14/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9006 - loss: 0.2812
# Epoch 14: val_accuracy did not improve from 0.60407
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - accuracy: 0.8983 - loss: 0.2854 - val_accuracy: 0.5988 - val_loss: 1.6557 - learning_rate: 2.5000e-05
# Epoch 15/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9121 - loss: 0.2508
# Epoch 15: val_accuracy did not improve from 0.60407
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9101 - loss: 0.2556 - val_accuracy: 0.6039 - val_loss: 1.6786 - learning_rate: 1.2500e-05
# Epoch 16/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9168 - loss: 0.2377
# Epoch 16: val_accuracy did not improve from 0.60407
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.9166 - loss: 0.2372 - val_accuracy: 0.5992 - val_loss: 1.7296 - learning_rate: 1.2500e-05
# Epoch 17/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9233 - loss: 0.2229
# Epoch 17: val_accuracy did not improve from 0.60407
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - accuracy: 0.9231 - loss: 0.2230 - val_accuracy: 0.5954 - val_loss: 1.7643 - learning_rate: 1.2500e-05
# Epoch 18/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9285 - loss: 0.2088
# Epoch 18: val_accuracy did not improve from 0.60407
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.9276 - loss: 0.2117 - val_accuracy: 0.5993 - val_loss: 1.8125 - learning_rate: 1.2500e-05
# Epoch 19/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9320 - loss: 0.1991
# Epoch 19: val_accuracy did not improve from 0.60407
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.9299 - loss: 0.2020 - val_accuracy: 0.5986 - val_loss: 1.8198 - learning_rate: 6.2500e-06
# Epoch 20/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9339 - loss: 0.1931
# Epoch 20: val_accuracy did not improve from 0.60407
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.9336 - loss: 0.1929 - val_accuracy: 0.5984 - val_loss: 1.8487 - learning_rate: 6.2500e-06
# Restoring model weights from the end of the best epoch: 13.
#
# ⏱  Training time: 5.6 min

# %%
print("=" * 60)
print("TRAINING MODEL 3: VGG-Style Double Conv Block")
print("=" * 60)

vgg_model = build_vgg_style_model()
history_vgg, time_vgg = compile_and_train(
    vgg_model, train_ds_gray, val_ds_gray,
    epochs=EPOCHS_SCRATCH, lr=1e-3, model_name='vgg_style'
)
plot_history(history_vgg, 'VGG-Style')
# Out:
# ============================================================
# TRAINING MODEL 3: VGG-Style Double Conv Block
# ============================================================
# Epoch 1/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2263 - loss: 1.8529
# Epoch 1: val_accuracy improved from None to 0.25453, saving model to best_vgg_style.keras
#
# Epoch 1: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 42ms/step - accuracy: 0.2515 - loss: 1.8009 - val_accuracy: 0.2545 - val_loss: 1.8061 - learning_rate: 0.0010
# Epoch 2/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3166 - loss: 1.6880
# Epoch 2: val_accuracy improved from 0.25453 to 0.33658, saving model to best_vgg_style.keras
#
# Epoch 2: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.3452 - loss: 1.6339 - val_accuracy: 0.3366 - val_loss: 1.7194 - learning_rate: 0.0010
# Epoch 3/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4140 - loss: 1.5014
# Epoch 3: val_accuracy improved from 0.33658 to 0.45305, saving model to best_vgg_style.keras
#
# Epoch 3: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.4272 - loss: 1.4714 - val_accuracy: 0.4531 - val_loss: 1.4202 - learning_rate: 0.0010
# Epoch 4/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4551 - loss: 1.4093
# Epoch 4: val_accuracy improved from 0.45305 to 0.46782, saving model to best_vgg_style.keras
#
# Epoch 4: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.4640 - loss: 1.3875 - val_accuracy: 0.4678 - val_loss: 1.3648 - learning_rate: 0.0010
# Epoch 5/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4849 - loss: 1.3404
# Epoch 5: val_accuracy improved from 0.46782 to 0.50362, saving model to best_vgg_style.keras
#
# Epoch 5: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.4910 - loss: 1.3297 - val_accuracy: 0.5036 - val_loss: 1.3096 - learning_rate: 0.0010
# Epoch 6/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5056 - loss: 1.2912
# Epoch 6: val_accuracy did not improve from 0.50362
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.5099 - loss: 1.2772 - val_accuracy: 0.4583 - val_loss: 1.3809 - learning_rate: 0.0010
# Epoch 7/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5239 - loss: 1.2536
# Epoch 7: val_accuracy did not improve from 0.50362
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.5228 - loss: 1.2493 - val_accuracy: 0.4921 - val_loss: 1.3083 - learning_rate: 0.0010
# Epoch 8/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5291 - loss: 1.2217
# Epoch 8: val_accuracy did not improve from 0.50362
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.5357 - loss: 1.2191 - val_accuracy: 0.4953 - val_loss: 1.2994 - learning_rate: 0.0010
# Epoch 9/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5440 - loss: 1.2047
# Epoch 9: val_accuracy improved from 0.50362 to 0.51296, saving model to best_vgg_style.keras
#
# Epoch 9: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.5475 - loss: 1.1959 - val_accuracy: 0.5130 - val_loss: 1.3116 - learning_rate: 0.0010
# Epoch 10/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5619 - loss: 1.1631
# Epoch 10: val_accuracy improved from 0.51296 to 0.53511, saving model to best_vgg_style.keras
#
# Epoch 10: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.5574 - loss: 1.1732 - val_accuracy: 0.5351 - val_loss: 1.2267 - learning_rate: 0.0010
# Epoch 11/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5572 - loss: 1.1576
# Epoch 11: val_accuracy improved from 0.53511 to 0.55698, saving model to best_vgg_style.keras
#
# Epoch 11: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.5616 - loss: 1.1600 - val_accuracy: 0.5570 - val_loss: 1.1523 - learning_rate: 0.0010
# Epoch 12/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5678 - loss: 1.1505
# Epoch 12: val_accuracy improved from 0.55698 to 0.56757, saving model to best_vgg_style.keras
#
# Epoch 12: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.5700 - loss: 1.1419 - val_accuracy: 0.5676 - val_loss: 1.1383 - learning_rate: 0.0010
# Epoch 13/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5797 - loss: 1.1252
# Epoch 13: val_accuracy improved from 0.56757 to 0.57857, saving model to best_vgg_style.keras
#
# Epoch 13: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.5762 - loss: 1.1272 - val_accuracy: 0.5786 - val_loss: 1.1186 - learning_rate: 0.0010
# Epoch 14/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5807 - loss: 1.1169
# Epoch 14: val_accuracy did not improve from 0.57857
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.5812 - loss: 1.1145 - val_accuracy: 0.5719 - val_loss: 1.1194 - learning_rate: 0.0010
# Epoch 15/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5872 - loss: 1.0972
# Epoch 15: val_accuracy did not improve from 0.57857
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.5894 - loss: 1.0965 - val_accuracy: 0.5752 - val_loss: 1.1043 - learning_rate: 0.0010
# Epoch 16/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5881 - loss: 1.0937
# Epoch 16: val_accuracy did not improve from 0.57857
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.5930 - loss: 1.0902 - val_accuracy: 0.5428 - val_loss: 1.2692 - learning_rate: 0.0010
# Epoch 17/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6020 - loss: 1.0699
# Epoch 17: val_accuracy improved from 0.57857 to 0.58080, saving model to best_vgg_style.keras
#
# Epoch 17: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.5989 - loss: 1.0719 - val_accuracy: 0.5808 - val_loss: 1.1264 - learning_rate: 0.0010
# Epoch 18/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6033 - loss: 1.0641
# Epoch 18: val_accuracy improved from 0.58080 to 0.59613, saving model to best_vgg_style.keras
#
# Epoch 18: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6054 - loss: 1.0586 - val_accuracy: 0.5961 - val_loss: 1.0605 - learning_rate: 0.0010
# Epoch 19/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6087 - loss: 1.0474
# Epoch 19: val_accuracy did not improve from 0.59613
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.6078 - loss: 1.0512 - val_accuracy: 0.4790 - val_loss: 1.4525 - learning_rate: 0.0010
# Epoch 20/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6073 - loss: 1.0455
# Epoch 20: val_accuracy improved from 0.59613 to 0.59933, saving model to best_vgg_style.keras
#
# Epoch 20: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6116 - loss: 1.0368 - val_accuracy: 0.5993 - val_loss: 1.0537 - learning_rate: 0.0010
# Epoch 21/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6118 - loss: 1.0254
# Epoch 21: val_accuracy improved from 0.59933 to 0.60309, saving model to best_vgg_style.keras
#
# Epoch 21: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6142 - loss: 1.0235 - val_accuracy: 0.6031 - val_loss: 1.0433 - learning_rate: 0.0010
# Epoch 22/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6212 - loss: 1.0163
# Epoch 22: val_accuracy did not improve from 0.60309
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6222 - loss: 1.0165 - val_accuracy: 0.5945 - val_loss: 1.0820 - learning_rate: 0.0010
# Epoch 23/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6294 - loss: 0.9962
# Epoch 23: val_accuracy did not improve from 0.60309
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6233 - loss: 1.0071 - val_accuracy: 0.5978 - val_loss: 1.0848 - learning_rate: 0.0010
# Epoch 24/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6294 - loss: 0.9943
# Epoch 24: val_accuracy improved from 0.60309 to 0.60825, saving model to best_vgg_style.keras
#
# Epoch 24: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6296 - loss: 0.9934 - val_accuracy: 0.6082 - val_loss: 1.0585 - learning_rate: 0.0010
# Epoch 25/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6370 - loss: 0.9766
# Epoch 25: val_accuracy did not improve from 0.60825
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6330 - loss: 0.9884 - val_accuracy: 0.5965 - val_loss: 1.0529 - learning_rate: 0.0010
# Epoch 26/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6467 - loss: 0.9527
# Epoch 26: val_accuracy did not improve from 0.60825
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6479 - loss: 0.9503 - val_accuracy: 0.6007 - val_loss: 1.0519 - learning_rate: 5.0000e-04
# Epoch 27/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6546 - loss: 0.9238
# Epoch 27: val_accuracy improved from 0.60825 to 0.62650, saving model to best_vgg_style.keras
#
# Epoch 27: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.6507 - loss: 0.9366 - val_accuracy: 0.6265 - val_loss: 0.9968 - learning_rate: 5.0000e-04
# Epoch 28/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6609 - loss: 0.9215
# Epoch 28: val_accuracy improved from 0.62650 to 0.63221, saving model to best_vgg_style.keras
#
# Epoch 28: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6564 - loss: 0.9288 - val_accuracy: 0.6322 - val_loss: 0.9833 - learning_rate: 5.0000e-04
# Epoch 29/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6602 - loss: 0.9210
# Epoch 29: val_accuracy did not improve from 0.63221
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6592 - loss: 0.9228 - val_accuracy: 0.6308 - val_loss: 0.9860 - learning_rate: 5.0000e-04
# Epoch 30/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6643 - loss: 0.9060
# Epoch 30: val_accuracy improved from 0.63221 to 0.63458, saving model to best_vgg_style.keras
#
# Epoch 30: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6623 - loss: 0.9110 - val_accuracy: 0.6346 - val_loss: 0.9762 - learning_rate: 5.0000e-04
# Epoch 31/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6615 - loss: 0.9144
# Epoch 31: val_accuracy improved from 0.63458 to 0.63527, saving model to best_vgg_style.keras
#
# Epoch 31: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6610 - loss: 0.9115 - val_accuracy: 0.6353 - val_loss: 0.9754 - learning_rate: 5.0000e-04
# Epoch 32/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6648 - loss: 0.9028
# Epoch 32: val_accuracy did not improve from 0.63527
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6626 - loss: 0.9069 - val_accuracy: 0.6290 - val_loss: 1.0023 - learning_rate: 5.0000e-04
# Epoch 33/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6746 - loss: 0.8870
# Epoch 33: val_accuracy improved from 0.63527 to 0.63597, saving model to best_vgg_style.keras
#
# Epoch 33: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.6690 - loss: 0.8958 - val_accuracy: 0.6360 - val_loss: 0.9703 - learning_rate: 5.0000e-04
# Epoch 34/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6744 - loss: 0.8877
# Epoch 34: val_accuracy improved from 0.63597 to 0.63736, saving model to best_vgg_style.keras
#
# Epoch 34: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.6708 - loss: 0.8888 - val_accuracy: 0.6374 - val_loss: 0.9798 - learning_rate: 5.0000e-04
# Epoch 35/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6769 - loss: 0.8783
# Epoch 35: val_accuracy did not improve from 0.63736
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.6737 - loss: 0.8837 - val_accuracy: 0.6330 - val_loss: 0.9848 - learning_rate: 5.0000e-04
# Epoch 36/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6791 - loss: 0.8734
# Epoch 36: val_accuracy improved from 0.63736 to 0.64029, saving model to best_vgg_style.keras
#
# Epoch 36: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6736 - loss: 0.8811 - val_accuracy: 0.6403 - val_loss: 0.9650 - learning_rate: 5.0000e-04
# Epoch 37/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6810 - loss: 0.8658
# Epoch 37: val_accuracy did not improve from 0.64029
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6760 - loss: 0.8760 - val_accuracy: 0.6389 - val_loss: 0.9700 - learning_rate: 5.0000e-04
# Epoch 38/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6771 - loss: 0.8623
# Epoch 38: val_accuracy improved from 0.64029 to 0.64308, saving model to best_vgg_style.keras
#
# Epoch 38: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6767 - loss: 0.8688 - val_accuracy: 0.6431 - val_loss: 0.9685 - learning_rate: 5.0000e-04
# Epoch 39/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6839 - loss: 0.8561
# Epoch 39: val_accuracy did not improve from 0.64308
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6798 - loss: 0.8666 - val_accuracy: 0.6361 - val_loss: 0.9842 - learning_rate: 5.0000e-04
# Epoch 40/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6809 - loss: 0.8602
# Epoch 40: val_accuracy improved from 0.64308 to 0.64447, saving model to best_vgg_style.keras
#
# Epoch 40: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6795 - loss: 0.8637 - val_accuracy: 0.6445 - val_loss: 0.9633 - learning_rate: 5.0000e-04
# Epoch 41/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6826 - loss: 0.8501
# Epoch 41: val_accuracy improved from 0.64447 to 0.64698, saving model to best_vgg_style.keras
#
# Epoch 41: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6803 - loss: 0.8572 - val_accuracy: 0.6470 - val_loss: 0.9587 - learning_rate: 5.0000e-04
# Epoch 42/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6876 - loss: 0.8389
# Epoch 42: val_accuracy did not improve from 0.64698
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6842 - loss: 0.8515 - val_accuracy: 0.6194 - val_loss: 1.0491 - learning_rate: 5.0000e-04
# Epoch 43/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6929 - loss: 0.8378
# Epoch 43: val_accuracy did not improve from 0.64698
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.6885 - loss: 0.8474 - val_accuracy: 0.6408 - val_loss: 0.9763 - learning_rate: 5.0000e-04
# Epoch 44/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6877 - loss: 0.8446
# Epoch 44: val_accuracy did not improve from 0.64698
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6896 - loss: 0.8472 - val_accuracy: 0.6354 - val_loss: 0.9889 - learning_rate: 5.0000e-04
# Epoch 45/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6867 - loss: 0.8453
# Epoch 45: val_accuracy did not improve from 0.64698
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.6888 - loss: 0.8439 - val_accuracy: 0.6318 - val_loss: 1.0061 - learning_rate: 5.0000e-04
# Epoch 46/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6955 - loss: 0.8201
# Epoch 46: val_accuracy improved from 0.64698 to 0.64921, saving model to best_vgg_style.keras
#
# Epoch 46: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6970 - loss: 0.8179 - val_accuracy: 0.6492 - val_loss: 0.9620 - learning_rate: 2.5000e-04
# Epoch 47/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7045 - loss: 0.8039
# Epoch 47: val_accuracy did not improve from 0.64921
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7020 - loss: 0.8093 - val_accuracy: 0.6445 - val_loss: 0.9692 - learning_rate: 2.5000e-04
# Epoch 48/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7002 - loss: 0.8119
# Epoch 48: val_accuracy improved from 0.64921 to 0.65227, saving model to best_vgg_style.keras
#
# Epoch 48: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7016 - loss: 0.8095 - val_accuracy: 0.6523 - val_loss: 0.9559 - learning_rate: 2.5000e-04
# Epoch 49/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6998 - loss: 0.8092
# Epoch 49: val_accuracy did not improve from 0.65227
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7045 - loss: 0.8009 - val_accuracy: 0.6503 - val_loss: 0.9642 - learning_rate: 2.5000e-04
# Epoch 50/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7057 - loss: 0.8042
# Epoch 50: val_accuracy did not improve from 0.65227
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.7055 - loss: 0.7973 - val_accuracy: 0.6500 - val_loss: 0.9584 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 48.
#
# ⏱  Training time: 7.9 min

# %% [markdown]
# ## Section 6.5 — Load Best Saved Models

# %%
best_scratch = tf.keras.models.load_model('best_scratch_cnn.keras')
best_frozen = tf.keras.models.load_model('best_mobilenet_frozen.keras')
best_finetune = tf.keras.models.load_model('best_mobilenet_finetuned.keras')
best_vgg = tf.keras.models.load_model('best_vgg_style.keras')
print("All best models loaded.")
# Out:
# All best models loaded.

# %%
def evaluate_model(model, val_ds, model_name):
    y_true, y_pred=[], []
    for batch_imgs, batch_labels in val_ds:
        preds = model.predict(batch_imgs, verbose=0)
        y_pred.extend(np.argmax(preds, axis=1))
        y_true.extend(np.argmax(batch_labels.numpy(), axis=1))

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    print(f"\n{'='*60}")
    print(f"Model: {model_name}")
    print('='*60)
    print(classification_report(y_true, y_pred, target_names=EMOTIONS))
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=EMOTIONS, yticklabels=EMOTIONS, linewidths=0.5)
    plt.title(f'{model_name} — Confusion Matrix (7×7)', fontsize=13, fontweight='bold')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.savefig(f'confusion_matrix_{model_name.lower().replace(" ","_")}.png',
                dpi=150, bbox_inches='tight')
    plt.show()
    macro_f1 = f1_score(y_true, y_pred, average='macro')
    acc = np.mean(y_true == y_pred)
    return acc, macro_f1
results = {}
results['CNN Scratch'] = evaluate_model(best_scratch,val_ds_gray,  'CNN Scratch')
results['MobileNet Frozen'] = evaluate_model(best_frozen,val_ds_color, 'MobileNet Frozen')
results['MobileNet Finetune'] = evaluate_model(best_finetune, val_ds_color, 'MobileNet Finetune')
results['VGG-Style'] = evaluate_model(best_vgg,val_ds_gray,  'VGG-Style')
# Out:
# ============================================================
# Model: CNN Scratch
# ============================================================
#               precision    recall  f1-score   support
#
#        angry       0.63      0.61      0.62       958
#      disgust       0.77      0.60      0.68       111
#         fear       0.56      0.44      0.49      1024
#        happy       0.85      0.88      0.86      1774
#      neutral       0.61      0.68      0.64      1233
#          sad       0.55      0.56      0.55      1247
#     surprise       0.78      0.80      0.79       831
#
#     accuracy                           0.68      7178
#    macro avg       0.68      0.65      0.66      7178
# weighted avg       0.67      0.68      0.67      7178
# ============================================================
# Model: MobileNet Frozen
# ============================================================
#               precision    recall  f1-score   support
#
#        angry       0.41      0.42      0.42       958
#      disgust       0.49      0.37      0.42       111
#         fear       0.45      0.29      0.35      1024
#        happy       0.69      0.68      0.69      1774
#      neutral       0.47      0.55      0.50      1233
#          sad       0.42      0.47      0.44      1247
#     surprise       0.66      0.71      0.68       831
#
#     accuracy                           0.53      7178
#    macro avg       0.51      0.50      0.50      7178
# weighted avg       0.53      0.53      0.52      7178
# ============================================================
# Model: MobileNet Finetune
# ============================================================
#               precision    recall  f1-score   support
#
#        angry       0.48      0.55      0.51       958
#      disgust       0.68      0.48      0.56       111
#         fear       0.53      0.42      0.46      1024
#        happy       0.79      0.80      0.80      1774
#      neutral       0.51      0.58      0.54      1233
#          sad       0.49      0.47      0.48      1247
#     surprise       0.75      0.75      0.75       831
#
#     accuracy                           0.60      7178
#    macro avg       0.60      0.58      0.59      7178
# weighted avg       0.61      0.60      0.60      7178
# ============================================================
# Model: VGG-Style
# ============================================================
#               precision    recall  f1-score   support
#
#        angry       0.58      0.56      0.57       958
#      disgust       0.66      0.39      0.49       111
#         fear       0.50      0.34      0.40      1024
#        happy       0.84      0.87      0.86      1774
#      neutral       0.60      0.68      0.63      1233
#          sad       0.52      0.54      0.53      1247
#     surprise       0.73      0.83      0.78       831
#
#     accuracy                           0.65      7178
#    macro avg       0.63      0.60      0.61      7178
# weighted avg       0.64      0.65      0.64      7178

# %%
param_counts = {
    'CNN Scratch': best_scratch.count_params(),
    'MobileNet Frozen': best_frozen.count_params(),
    'MobileNet Finetune': best_finetune.count_params(),
    'VGG-Style': best_vgg.count_params(),
}
train_times = {
    'CNN Scratch': time_scratch,
    'MobileNet Frozen': time_frozen,
    'MobileNet Finetune': time_finetune,
    'VGG-Style': time_vgg,
}
comparison_df = pd.DataFrame({
    'Model': list(results.keys()),
    'Val Accuracy': [f'{v[0]*100:.2f}%' for v in results.values()],
    'Macro F1': [f'{v[1]:.4f}'      for v in results.values()],
    'Parameters': [f'{param_counts[k]:,}' for k in results],
    'Train Time(s)': [f'{train_times[k]:.0f}s' for k in results],
})
print("\n" + "="*70)
print(" MODEL COMPARISON TABLE")
print("="*70)
print(comparison_df.to_string(index=False))
best_model_name = max(results, key=lambda k: results[k][0])
print(f"\nBest model: {best_model_name} "
      f"(val accuracy = {results[best_model_name][0]*100:.2f}%)")
# Out:
# ======================================================================
#  MODEL COMPARISON TABLE
# ======================================================================
#              Model Val Accuracy Macro F1 Parameters Train Time(s)
#        CNN Scratch       67.71%   0.6617    323,047          472s
#   MobileNet Frozen       52.74%   0.5003  3,046,983          306s
# MobileNet Finetune       60.41%   0.5859  3,046,983          335s
#          VGG-Style       65.23%   0.6091    487,399          477s
#
# Best model: CNN Scratch (val accuracy = 67.71%)

# %%
model_map = {
    'CNN Scratch': (best_scratch,'gray'),
    'MobileNet Frozen': (best_frozen,'color'),
    'MobileNet Finetune': (best_finetune,'color'),
    'VGG-Style': (best_vgg,'gray'),
}
DEPLOY_MODEL, DEPLOY_MODE = model_map[best_model_name]
DEPLOY_MODEL.save('emotion_model_deploy.h5')
print(f"Saved best model ({best_model_name}) → emotion_model_deploy.h5")
print(f"Input mode: {DEPLOY_MODE}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved best model (CNN Scratch) → emotion_model_deploy.h5
# Input mode: gray

# %%
from google.colab import files
files.download("emotion_model_deploy.h5")

# %%
model_map = {
    'CNN Scratch': (best_scratch,'gray'),
    'MobileNet Frozen': (best_frozen,'color'),
    'MobileNet Finetune': (best_finetune,'color'),
    'VGG-Style': (best_vgg,'gray'),
}
DEPLOY_MODEL, DEPLOY_MODE = model_map[best_model_name]
DEPLOY_MODEL.save('emotion_model_deploy.keras',include_optimizer=False)
print(f"Saved best model ({best_model_name}) → emotion_model_deploy.keras")
print(f"Input mode: {DEPLOY_MODE}")
# Out:
# Saved best model (CNN Scratch) → emotion_model_deploy.keras
# Input mode: gray

# %%
from google.colab import files
files.download("emotion_model_deploy.keras")

# %%
import tensorflow as tf
model = tf.keras.models.load_model("/content/emotion_model_deploy.keras", compile=False)
model.save("fixed_model.keras")

# %%
from google.colab import files
files.download("fixed_model.keras")

# %%
print("\n" + "="*65)
print(" LAB 14 — FINAL SUMMARY")
print("="*65)
print(f"Best Model       : {best_model_name}")
print(f"Val Accuracy     : {results[best_model_name][0]*100:.2f}%")
print(f"Macro F1-Score   : {results[best_model_name][1]:.4f}")
print(f"Parameters       : {param_counts[best_model_name]:,}")
print()
# Out:
# =================================================================
#  LAB 14 — FINAL SUMMARY
# =================================================================
# Best Model       : CNN Scratch
# Val Accuracy     : 67.71%
# Macro F1-Score   : 0.6617
# Parameters       : 323,047
